# %% [markdown]
# ### Libraries

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import zipfile
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
from shutil import move, rmtree
import random
from itertools import repeat
from collections import Counter
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy, categorical_crossentropy
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from PIL import Image
import albumentations as A
seed = 1
tf.random.set_seed(
    seed
)
np.random.seed(seed)
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
import warnings
warnings.simplefilter(action='ignore')
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base has been moved to tensorflow.python.trackable.base. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.checkpoint_management has been moved to tensorflow.python.checkpoint.checkpoint_management. The old module will be deleted in version 2.9.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.resource has been moved to tensorflow.python.trackable.resource. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base_delegate has been moved to tensorflow.python.trackable.base_delegate. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.graph_view has been moved to tensorflow.python.checkpoint.graph_view. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.python_state has been moved to tensorflow.python.trackable.python_state. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.functional_saver has been moved to tensorflow.python.checkpoint.functional_saver. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.checkpoint_options has been moved to tensorflow.python.checkpoint.checkpoint_options. The old module will be deleted in version 2.11.

# %% [markdown]
# ### Read Data

# %%
if os.path.isdir('./Data'):
    rmtree('./Data')
local_zip = './archive.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./Data')
zip_ref.close()

# %%
filenames = os.listdir('./Data/dataset/')
print('Classes: ', filenames)
print('The number Classes: ', len(filenames))
# Out:
# Classes:  ['glaze', 'sandstorm', 'rime', 'snow', 'lightning', 'hail', 'rain', 'fogsmog', 'dew', 'rainbow', 'frost']
# The number Classes:  11

# %% [markdown]
# ### EDA

# %%
imgnum = []
for file in filenames:
    temp = os.path.join('./Data/dataset/'+file+'/')
    print('The number of Images in {}: {}'.format(file, len(os.listdir(temp))))
    imgnum.append(len(os.listdir(temp)))
# Out:
# The number of Images in glaze: 639
# The number of Images in sandstorm: 692
# The number of Images in rime: 1160
# The number of Images in snow: 621
# The number of Images in lightning: 377
# The number of Images in hail: 591
# The number of Images in rain: 526
# The number of Images in fogsmog: 851
# The number of Images in dew: 698
# The number of Images in rainbow: 232
# The number of Images in frost: 475

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(filenames, imgnum, width=0.4)
plt.xlabel('Classes')
plt.ylabel('Counter')
plt.title('The number of Images per Class')
# Out:
# Text(0.5, 1.0, 'The number of Images per Class')

# %%
fig, axes = plt.subplots(1, 6)
fig.set_size_inches(20,2)
for ax, file in zip(axes, filenames[:6]):
    temp ='./Data/dataset/'+file+'/'
    sample = cv2.imread(temp+os.listdir(temp)[0], cv2.IMREAD_COLOR)
    ax.imshow(sample)
    ax.axis('off')
    ax.set_title(file)

# %%
fig, axes = plt.subplots(1, 5)
fig.set_size_inches(20,2)
for ax, file in zip(axes, filenames[6:]):
    temp ='./Data/dataset/'+file+'/'
    sample = cv2.imread(temp+os.listdir(temp)[0], cv2.IMREAD_COLOR)
    ax.imshow(sample)
    ax.axis('off')
    ax.set_title(file)

# %% [markdown]
# ### Split_Data

# %%
def new_dir(path, folder_name):
    diric = str(path)+str(folder_name)+'/'
    if not os.path.exists(diric):
        os.mkdir(diric)
        print(diric + ' is created..!')
        return diric
    else:
        print('Dir is exists .. !')
        return diric
def move_files(filename, dest):
    print(f'Working on file: {filename}')
    if os.path.exists(str(dest)+str(filename)):
        print('The file is exists ...')
    else:
        move(filename, dest)
def split_into_testset(path, path2, folders, perc):
    for folder in folders:
        dir_file_list = []
        temp = os.path.join('./Data/'+path2+'/'+folder+'/')
        img_data = os.listdir(temp)
        for img in img_data:
            org_path = str(temp) + str(img)
            dir_file_list.append(org_path)
        des_file = new_dir(path, folder)
        print(f'The destination path: {des_file}')
        k = int(len(img_data) * perc)
        print(f'The number of moved files: {k}')
        picked_files = random.sample(dir_file_list, k=k)
        for mv in picked_files:
            move_files(mv, des_file)

# %%
path ='Data/'
folder_name = {'val_dataset':0.3, 'test_dataset':0.5}
path2  = ['dataset', 'val_dataset']
i=0
for k, v in folder_name.items():
    new_folder_path = new_dir(path, k)
    split_into_testset(new_folder_path, path2[i], filenames, v)
    i+=1
# Out:
# Data/val_dataset/ is created..!
# Data/val_dataset/glaze/ is created..!
# The destination path: Data/val_dataset/glaze/
# The number of moved files: 191
# Working on file: ./Data/dataset/glaze/6633.jpg
# Working on file: ./Data/dataset/glaze/6672.jpg
# Working on file: ./Data/dataset/glaze/6449.jpg
# Working on file: ./Data/dataset/glaze/6380.jpg
# Working on file: ./Data/dataset/glaze/6106.jpg
# Working on file: ./Data/dataset/glaze/6442.jpg
# Working on file: ./Data/dataset/glaze/6528.jpg
# Working on file: ./Data/dataset/glaze/6215.jpg
# Working on file: ./Data/dataset/glaze/6119.jpg
# Working on file: ./Data/dataset/glaze/6470.jpg
# Working on file: ./Data/dataset/glaze/6425.jpg
# Working on file: ./Data/dataset/glaze/6413.jpg
# Working on file: ./Data/dataset/glaze/6478.jpg
# Working on file: ./Data/dataset/glaze/6641.jpg
# Working on file: ./Data/dataset/glaze/6389.jpg
# Working on file: ./Data/dataset/glaze/6552.jpg
# Working on file: ./Data/dataset/glaze/6149.jpg
# Working on file: ./Data/dataset/glaze/6404.jpg
# Working on file: ./Data/dataset/glaze/6117.jpg
# Working on file: ./Data/dataset/glaze/6438.jpg
# Working on file: ./Data/dataset/glaze/6424.jpg
# Working on file: ./Data/dataset/glaze/6556.jpg
# Working on file: ./Data/dataset/glaze/6160.jpg
# Working on file: ./Data/dataset/glaze/6279.jpg
# Working on file: ./Data/dataset/glaze/6345.jpg
# Working on file: ./Data/dataset/glaze/6139.jpg
# Working on file: ./Data/dataset/glaze/6726.jpg
# Working on file: ./Data/dataset/glaze/6353.jpg
# Working on file: ./Data/dataset/glaze/6500.jpg
# Working on file: ./Data/dataset/glaze/6542.jpg
# Working on file: ./Data/dataset/glaze/6135.jpg
# Working on file: ./Data/dataset/glaze/6666.jpg
# Working on file: ./Data/dataset/glaze/6585.jpg
# Working on file: ./Data/dataset/glaze/6401.jpg
# Working on file: ./Data/dataset/glaze/6609.jpg
# Working on file: ./Data/dataset/glaze/6258.jpg
# Working on file: ./Data/dataset/glaze/6717.jpg
# Working on file: ./Data/dataset/glaze/6545.jpg
# Working on file: ./Data/dataset/glaze/6239.jpg
# Working on file: ./Data/dataset/glaze/6367.jpg
# Working on file: ./Data/dataset/glaze/6099.jpg
# Working on file: ./Data/dataset/glaze/6322.jpg
# Working on file: ./Data/dataset/glaze/6712.jpg
# Working on file: ./Data/dataset/glaze/6232.jpg
# Working on file: ./Data/dataset/glaze/6492.jpg
# Working on file: ./Data/dataset/rime/5419.jpg
# Working on file: ./Data/dataset/rime/5714.jpg
# Working on file: ./Data/dataset/rime/5386.jpg
# Working on file: ./Data/dataset/rime/5105.jpg
# Working on file: ./Data/dataset/rime/5272.jpg
# Working on file: ./Data/dataset/rime/5197.jpg
# Working on file: ./Data/dataset/rime/6079.jpg
# Working on file: ./Data/dataset/rime/6032.jpg
# Data/val_dataset/snow/ is created..!
# The destination path: Data/val_dataset/snow/
# The number of moved files: 186
# Working on file: ./Data/dataset/snow/0953.jpg
# Working on file: ./Data/dataset/snow/0927.jpg
# Working on file: ./Data/dataset/snow/1444.jpg
# Working on file: ./Data/dataset/snow/1437.jpg
# Working on file: ./Data/dataset/snow/0922.jpg
# Working on file: ./Data/dataset/snow/1364.jpg
# Working on file: ./Data/dataset/snow/0875.jpg
# Working on file: ./Data/dataset/snow/1009.jpg
# Working on file: ./Data/dataset/snow/1258.jpg
# Working on file: ./Data/dataset/snow/1069.jpg
# Working on file: ./Data/dataset/snow/1283.jpg
# Working on file: ./Data/dataset/snow/0918.jpg
# Working on file: ./Data/dataset/snow/1348.jpg
# Working on file: ./Data/dataset/snow/1310.jpg
# Working on file: ./Data/dataset/snow/1002.jpg
# Working on file: ./Data/dataset/snow/0923.jpg
# Working on file: ./Data/dataset/snow/0876.jpg
# Working on file: ./Data/dataset/snow/1089.jpg
# Working on file: ./Data/dataset/snow/0877.jpg
# Working on file: ./Data/dataset/snow/1191.jpg
# Working on file: ./Data/dataset/snow/1027.jpg
# Working on file: ./Data/dataset/snow/1001.jpg
# Working on file: ./Data/dataset/snow/0960.jpg
# Working on file: ./Data/dataset/snow/1018.jpg
# Working on file: ./Data/dataset/snow/1343.jpg
# Working on file: ./Data/dataset/snow/1242.jpg
# Working on file: ./Data/dataset/snow/1193.jpg
# Working on file: ./Data/dataset/snow/1235.jpg
# Working on file: ./Data/dataset/snow/0847.jpg
# Working on file: ./Data/dataset/snow/1217.jpg
# Working on file: ./Data/dataset/snow/1292.jpg
# Working on file: ./Data/dataset/snow/0831.jpg
# Working on file: ./Data/dataset/snow/0941.jpg
# Working on file: ./Data/dataset/snow/1345.jpg
# Working on file: ./Data/dataset/snow/0858.jpg
# Working on file: ./Data/dataset/snow/1008.jpg
# Working on file: ./Data/dataset/snow/1247.jpg
# Working on file: ./Data/dataset/snow/1174.jpg
# Working on file: ./Data/dataset/snow/1419.jpg
# Working on file: ./Data/dataset/snow/1112.jpg
# Working on file: ./Data/dataset/snow/1203.jpg
# Working on file: ./Data/dataset/snow/1086.jpg
# Working on file: ./Data/dataset/snow/0972.jpg
# Working on file: ./Data/dataset/snow/0864.jpg
# Working on file: ./Data/dataset/snow/1352.jpg
# Working on file: ./Data/dataset/snow/1172.jpg
# Working on file: ./Data/dataset/snow/1408.jpg
# Working on file: ./Data/dataset/snow/0836.jpg
# Working on file: ./Data/dataset/snow/1030.jpg
# Working on file: ./Data/dataset/snow/1241.jpg
# Working on file: ./Data/dataset/snow/1131.jpg
# Working on file: ./Data/dataset/snow/1269.jpg
# Working on file: ./Data/dataset/snow/1144.jpg
# Working on file: ./Data/dataset/snow/1091.jpg
# Working on file: ./Data/dataset/snow/1416.jpg
# Working on file: ./Data/dataset/snow/1149.jpg
# Working on file: ./Data/dataset/snow/1319.jpg
# Working on file: ./Data/dataset/snow/0844.jpg
# Working on file: ./Data/dataset/snow/0968.jpg
# Working on file: ./Data/dataset/snow/1442.jpg
# Working on file: ./Data/dataset/snow/1263.jpg
# Working on file: ./Data/dataset/snow/0940.jpg
# Working on file: ./Data/dataset/snow/1198.jpg
# Working on file: ./Data/dataset/snow/1281.jpg
# Working on file: ./Data/dataset/snow/1119.jpg
# Working on file: ./Data/dataset/snow/0870.jpg
# Working on file: ./Data/dataset/snow/1356.jpg
# Working on file: ./Data/dataset/snow/1400.jpg
# Working on file: ./Data/dataset/snow/1363.jpg
# Working on file: ./Data/dataset/snow/1302.jpg
# Working on file: ./Data/dataset/snow/0865.jpg
# Working on file: ./Data/dataset/snow/1362.jpg
# Working on file: ./Data/dataset/snow/1182.jpg
# Working on file: ./Data/dataset/snow/0965.jpg
# Working on file: ./Data/dataset/snow/1280.jpg
# Working on file: ./Data/dataset/snow/0857.jpg
# Working on file: ./Data/dataset/snow/1076.jpg
# Working on file: ./Data/dataset/snow/0909.jpg
# Working on file: ./Data/dataset/snow/0991.jpg
# Working on file: ./Data/dataset/snow/1230.jpg
# Working on file: ./Data/dataset/snow/0833.jpg
# Working on file: ./Data/dataset/snow/0853.jpg
# Working on file: ./Data/dataset/snow/0937.jpg
# Working on file: ./Data/dataset/snow/0861.jpg
# Working on file: ./Data/dataset/snow/1109.jpg
# Working on file: ./Data/dataset/snow/1125.jpg
# Working on file: ./Data/dataset/snow/1386.jpg
# Working on file: ./Data/dataset/snow/0950.jpg
# Working on file: ./Data/dataset/snow/1322.jpg
# Working on file: ./Data/dataset/snow/1192.jpg
# Working on file: ./Data/dataset/snow/1159.jpg
# Working on file: ./Data/dataset/snow/1447.jpg
# Working on file: ./Data/dataset/snow/1163.jpg
# Working on file: ./Data/dataset/snow/1328.jpg
# Working on file: ./Data/dataset/snow/1339.jpg
# Working on file: ./Data/dataset/snow/0999.jpg
# Working on file: ./Data/dataset/snow/0945.jpg
# Working on file: ./Data/dataset/snow/0975.jpg
# Working on file: ./Data/dataset/snow/1261.jpg
# Working on file: ./Data/dataset/snow/1053.jpg
# Working on file: ./Data/dataset/snow/0985.jpg
# Working on file: ./Data/dataset/snow/1250.jpg
# Working on file: ./Data/dataset/snow/1297.jpg
# Working on file: ./Data/dataset/snow/0979.jpg
# Working on file: ./Data/dataset/snow/1044.jpg
# Working on file: ./Data/dataset/snow/1290.jpg
# Working on file: ./Data/dataset/snow/0993.jpg
# Working on file: ./Data/dataset/snow/1200.jpg
# Working on file: ./Data/dataset/snow/1150.jpg
# Working on file: ./Data/dataset/snow/1138.jpg
# Working on file: ./Data/dataset/snow/1152.jpg
# Working on file: ./Data/dataset/snow/1062.jpg
# Working on file: ./Data/dataset/snow/1417.jpg
# Working on file: ./Data/dataset/snow/0848.jpg
# Working on file: ./Data/dataset/snow/1262.jpg
# Working on file: ./Data/dataset/snow/0948.jpg
# Working on file: ./Data/dataset/snow/1354.jpg
# Working on file: ./Data/dataset/snow/1019.jpg
# Working on file: ./Data/dataset/snow/1413.jpg
# Working on file: ./Data/dataset/snow/1058.jpg
# Working on file: ./Data/dataset/snow/1025.jpg
# Working on file: ./Data/dataset/snow/1117.jpg
# Working on file: ./Data/dataset/snow/1396.jpg
# Working on file: ./Data/dataset/snow/1012.jpg
# Working on file: ./Data/dataset/snow/1045.jpg
# Working on file: ./Data/dataset/snow/0982.jpg
# Working on file: ./Data/dataset/snow/1196.jpg
# Working on file: ./Data/dataset/snow/0955.jpg
# Working on file: ./Data/dataset/snow/1397.jpg
# Working on file: ./Data/dataset/snow/1446.jpg
# Working on file: ./Data/dataset/snow/1331.jpg
# Working on file: ./Data/dataset/snow/0956.jpg
# Working on file: ./Data/dataset/snow/1158.jpg
# Working on file: ./Data/dataset/snow/1366.jpg
# Working on file: ./Data/dataset/snow/1143.jpg
# Working on file: ./Data/dataset/snow/0899.jpg
# Working on file: ./Data/dataset/snow/0994.jpg
# Working on file: ./Data/dataset/snow/1423.jpg
# Working on file: ./Data/dataset/snow/1126.jpg
# Working on file: ./Data/dataset/snow/1028.jpg
# Working on file: ./Data/dataset/snow/0964.jpg
# Working on file: ./Data/dataset/snow/1243.jpg
# Working on file: ./Data/dataset/snow/0978.jpg
# Working on file: ./Data/dataset/snow/0973.jpg
# Working on file: ./Data/dataset/snow/1167.jpg
# Working on file: ./Data/dataset/snow/0910.jpg
# Working on file: ./Data/dataset/snow/1428.jpg
# Working on file: ./Data/dataset/snow/1418.jpg
# Working on file: ./Data/dataset/snow/1384.jpg
# Working on file: ./Data/dataset/snow/1136.jpg
# Working on file: ./Data/dataset/snow/0996.jpg
# Working on file: ./Data/dataset/snow/0995.jpg
# Working on file: ./Data/dataset/snow/1156.jpg
# Working on file: ./Data/dataset/snow/1231.jpg
# Working on file: ./Data/dataset/snow/1102.jpg
# Working on file: ./Data/dataset/snow/1111.jpg
# Working on file: ./Data/dataset/snow/0988.jpg
# Working on file: ./Data/dataset/snow/1108.jpg
# Working on file: ./Data/dataset/snow/0872.jpg
# Working on file: ./Data/dataset/snow/0976.jpg
# Working on file: ./Data/dataset/snow/1308.jpg
# Working on file: ./Data/dataset/snow/1173.jpg
# Working on file: ./Data/dataset/snow/0884.jpg
# Working on file: ./Data/dataset/snow/1207.jpg
# Working on file: ./Data/dataset/snow/0983.jpg
# Working on file: ./Data/dataset/snow/1015.jpg
# Working on file: ./Data/dataset/snow/1168.jpg
# Working on file: ./Data/dataset/snow/0862.jpg
# Working on file: ./Data/dataset/snow/1256.jpg
# Working on file: ./Data/dataset/snow/1361.jpg
# Working on file: ./Data/dataset/snow/1434.jpg
# Working on file: ./Data/dataset/snow/1441.jpg
# Working on file: ./Data/dataset/snow/0963.jpg
# Working on file: ./Data/val_dataset/frost/3744.jpg
# Working on file: ./Data/val_dataset/frost/3994.jpg
# Working on file: ./Data/val_dataset/frost/3742.jpg
# Working on file: ./Data/val_dataset/frost/3907.jpg
# Working on file: ./Data/val_dataset/frost/3603.jpg
# Working on file: ./Data/val_dataset/frost/3647.jpg
# Working on file: ./Data/val_dataset/frost/4070.jpg

# %%
train_img = {}
for file in filenames:
    temp = os.path.join('./Data/dataset/'+file+'/')
    print('The number of train Images in {}: {}'.format(file, len(os.listdir(temp))))
    # train_img.append(len(os.listdir(temp)))
    train_img[str(file)] = len(os.listdir(temp))
print(f'\nThe number of all images is: {sum(train_img.values())}')
# Out:
# The number of train Images in glaze: 448
# The number of train Images in sandstorm: 485
# The number of train Images in rime: 812
# The number of train Images in snow: 435
# The number of train Images in lightning: 264
# The number of train Images in hail: 414
# The number of train Images in rain: 369
# The number of train Images in fogsmog: 596
# The number of train Images in dew: 489
# The number of train Images in rainbow: 163
# The number of train Images in frost: 333
#
# The number of all images is: 4808

# %%
val_img = {}
for file in filenames:
    temp = os.path.join('./Data/val_dataset/'+file+'/')
    print('The number of train Images in {}: {}'.format(file, len(os.listdir(temp))))
    # val_img.append(len(os.listdir(temp)))
    val_img[str(file)] = len(os.listdir(temp))
print(f'\nThe number of all images is: {sum(val_img.values())}')
# Out:
# The number of train Images in glaze: 96
# The number of train Images in sandstorm: 104
# The number of train Images in rime: 174
# The number of train Images in snow: 93
# The number of train Images in lightning: 57
# The number of train Images in hail: 89
# The number of train Images in rain: 79
# The number of train Images in fogsmog: 128
# The number of train Images in dew: 105
# The number of train Images in rainbow: 35
# The number of train Images in frost: 71
#
# The number of all images is: 1031

# %%
test_img = {}
for file in filenames:
    temp = os.path.join('./Data/test_dataset/'+file+'/')
    print('The number of test Images in {}: {}'.format(file, len(os.listdir(temp))))
    # test_img.append(len(os.listdir(temp)))
    test_img[str(file)] = len(os.listdir(temp))
print(f'\nThe number of all images is: {sum(test_img.values())}')
# Out:
# The number of test Images in glaze: 95
# The number of test Images in sandstorm: 103
# The number of test Images in rime: 174
# The number of test Images in snow: 93
# The number of test Images in lightning: 56
# The number of test Images in hail: 88
# The number of test Images in rain: 78
# The number of test Images in fogsmog: 127
# The number of test Images in dew: 104
# The number of test Images in rainbow: 34
# The number of test Images in frost: 71
#
# The number of all images is: 1023

# %%
fig, ax = plt.subplots(3, 1)
fig.set_size_inches(10,10)
counter = 0
for s, v in zip(['Train', 'Validation', 'Test'], [train_img.values(), val_img.values(), test_img.values()]):
    ax[counter].bar(filenames, v, width=0.4)
    ax[counter].set_xlabel('Classes')
    ax[counter].set_ylabel(s+' Counter')
    counter+=1

# %% [markdown]
# ### Image Generator & Augmentation

# %%
def aug_data(path, trans, aug):
    for key, val in aug.items():
        temp = os.path.join(str(path)+key+'/')
        imgs = os.listdir(temp)
        if int(val) < 0:
            items = random.sample(imgs, k=abs(val))
            for i in items:
                item = os.path.join(temp, str(i))
                os.remove(item)
        else:
            count = 0
            while count < int(val):
                item = random.choice(imgs)
                item = os.path.join(temp, item)
                img = np.array(Image.open(item))
                transform = trans(image=img)['image']
                try:
                    img_trans = Image.fromarray(transform, 'RGB')
                    img_trans.save(os.path.join(temp, 'a'+str(count)+'.jpg'))
                    count+=1
                except Exception:
                    print('Can\'t Save Photo...')
transformer = A.Compose([
        A.RandomRotate90(),
        A.Flip(),
        A.Transpose(),
        A.OneOf([
            A.IAAAdditiveGaussianNoise(),
            A.GaussNoise(),
        ], p=0.2),
        A.OneOf([
            A.MotionBlur(p=.2),
            A.MedianBlur(blur_limit=3, p=0.1),
            A.Blur(blur_limit=3, p=0.1),
        ], p=0.2),
        A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.2, rotate_limit=45, p=0.2),
        A.OneOf([
            A.OpticalDistortion(p=0.3),
            A.GridDistortion(p=.1),
            A.IAAPiecewiseAffine(p=0.3),
        ], p=0.2),
        A.OneOf([
            A.IAASharpen(),
            A.IAAEmboss(),
            A.RandomBrightnessContrast(),            
        ], p=0.3),
    ])
p = './Data/dataset/'
d = {}
for k, v in train_img.items():
    n = 400 - v
    d[k]= n
print(d)
aug_data(p, transformer, d)
# Out:
# {'glaze': -48, 'sandstorm': -85, 'rime': -412, 'snow': -35, 'lightning': 136, 'hail': -14, 'rain': 31, 'fogsmog': -196, 'dew': -89, 'rainbow': 237, 'frost': 67}
# Can't Save Photo...

# %%
for file in filenames:
    temp = os.path.join('./Data/dataset/'+file+'/')
    print('The number of Images in {}: {}'.format(file, len(os.listdir(temp))))
# Out:
# The number of Images in glaze: 400
# The number of Images in sandstorm: 400
# The number of Images in rime: 400
# The number of Images in snow: 400
# The number of Images in lightning: 400
# The number of Images in hail: 400
# The number of Images in rain: 400
# The number of Images in fogsmog: 400
# The number of Images in dew: 400
# The number of Images in rainbow: 400
# The number of Images in frost: 400

# %%
train_datagen = ImageDataGenerator(
    rescale=1/255,
    # horizontal_flip=True,
    # rotation_range=0.3,
)
validation_datagen = ImageDataGenerator(
    rescale=1/255,
)
test_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
        './Data/dataset/',  
        target_size=(200, 400),  
        batch_size=128,
        class_mode='categorical')
val_generator = validation_datagen.flow_from_directory(
        './Data/val_dataset/',  
        target_size=(200, 400),  
        batch_size=32,
        class_mode='categorical')
test_generator = test_datagen.flow_from_directory(
        './Data/test_dataset/',  
        target_size=(200, 400),  
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 4400 images belonging to 11 classes.
# Found 1031 images belonging to 11 classes.
# Found 1023 images belonging to 11 classes.

# %%
# def to_dataFrame(gen):
#     dic = {'path':[], 'img_name':[], 'category':[], 'labels':[]}
#     labels = np.array(gen.labels)
#     class_indices = gen.class_indices
#     for key in class_indices.keys():
#         label = gen.class_indices.get(str(key))
#         for path in gen.filepaths:
#             chek = path.split('/')
#             if key in chek:
#                 dic['path'].append(path)
#                 dic['img_name'].append(chek[4])
#                 # img = Image.open(path)
#                 # img = np.asarray(img)
#                 # dic['img'].append(img)
#                 dic['category'].append(key)
#                 dic['labels'].append(label)
#     return dic
# train_df = pd.DataFrame(to_dataFrame(train_generator))
# val_df = pd.DataFrame(to_dataFrame(val_generator))
# test_df = pd.DataFrame(to_dataFrame(test_generator))
# train_df

# %% [markdown]
# ### CNN Model

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_loss') < 0.7) or (logs.get('val_accuracy') >= 0.8):
            print("\nCallback function cancelling training ...!")
            self.model.stop_training = True

# %%
model = tf.keras.models.Sequential([
    layers.Conv2D(8, (3, 3), activation=tf.nn.relu, input_shape=(200, 400, 3)),
    layers.MaxPool2D(2, 2),
    layers.Conv2D(16, (3, 3), activation=tf.nn.relu),
    layers.MaxPool2D(2, 2),
    layers.Conv2D(64, (3, 3), activation=tf.nn.relu),
    layers.MaxPool2D(2, 2),
    layers.Flatten(),
    layers.Dense(256, activation=tf.nn.relu),
    layers.Dropout(0.15),
    layers.Dense(11, activation=tf.nn.softmax)
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
callbacks = myCallback()
history = model.fit(
    train_generator,
    steps_per_epoch=12,
    # verbose=-1,
    epochs=50,
    validation_data=val_generator,
    validation_steps=12,
    callbacks=[callbacks]
)

# %%
test_loss = model.evaluate(test_generator)

# %% [markdown]
# ### Error Analysis

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()
tr_plot(history,0)

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names     
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)         
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):                
                split1=os.path.split(error_list[i])                
                split2=os.path.split(split1[0])                
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])               
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class 
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)        
    y_pred=np.array(y_pred)
    if len(classes)<= 30:
        # create a confusion matrix 
        cm = confusion_matrix(y_true, y_pred )        
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)
print_code=0
working_dir = r'./'
preds=model.predict(test_generator, steps=23, verbose=1)
subject = 'Weather'
print_info( test_generator, preds, print_code, working_dir, subject )

# %%
def miss_labeled(preds, gen):
    class_dict=gen.class_indices
    labels= gen.labels
    file_names= gen.filepaths
    new_dict={}
    for key,value in class_dict.items():
        new_dict[value]=key
    classes=list(new_dict.values()) 
    missing = {'img_path':[], 'predicted':[], 'actual':[]}
    for i, p in enumerate(preds):
            pred_index=np.argmax(p)
            true_index=labels[i]
            if pred_index != true_index:
                missing['img_path'].append(file_names[i])
                missing['actual'].append(new_dict[true_index])
                missing['predicted'].append(new_dict[pred_index])
    length = len(missing['img_path'])
    print(f'The number of Images that miss labeled: {length}')
    # print()
    # for k in Counter(missing['actual']).most_common(11):
    #     print(f'The number of miss labeled {list(k)[0]} Images is: {list(k)[1]}')
    df = pd.DataFrame(missing)
    x = np.array(random.sample(list(df.index), k=30)).reshape(5, 6)
    fig, ax = plt.subplots(5,6, figsize=(20,15))
    plt.rcParams.update({'font.size': 7})
    cont = 0
    for pic in range(5):
        for cont in range(6):
            value = x[pic][cont]
            pth = df.iloc[value]['img_path']
            pre = df.iloc[value]['predicted']
            act = df.iloc[value]['actual']
            sample = cv2.imread(pth, cv2.IMREAD_COLOR)
            ax[pic, cont].imshow(sample)
            ax[pic, cont].axis('off')
            ax[pic, cont].set_title('predict: '+str(pre)+'/'+'actual: '+str(act))
miss_labeled(preds, test_generator)
